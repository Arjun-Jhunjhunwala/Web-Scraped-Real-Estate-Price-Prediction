# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Raw Property.csv')

# %%
df
# Out:
#                                            Property_Name          Location  \
# 0                                     Kalpataru Radiance     Goregaon West
# 1                      Monte Verita North Annexe Phase 1     Borivali East
# 2      Sheth VASANTOASIS BLOSSOM BLDG 20 WING A AND W...            khopte
# 3                        DLH The Park Residences Phase 1      Andheri West
# 4                           Oberoi Eternia Towers A to D       Mulund West
# ...                                                  ...               ...
# 14995                                                NaN       Mulund West
# 14996                                                NaN    Santacruz East
# 14997                                                NaN    Mira Road West
# 14998                                                NaN     Borivali West
# 14999                                                NaN   Vile Parle East
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Property_Name', 'Location', 'Price', 'Built-up Area', 'Bedroom',
#        'Property_Age', 'Furnish'],
#       dtype='object')

# %%
nan_counts = df.isna().sum()
nan_counts
# Out:
# Property_Name    5060
# Location           31
# Price              31
# Built-up Area      31
# Bedroom            31
# Property_Age     2028
# Furnish            72
# dtype: int64

# %%
df=df.dropna(how='all')
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                            Property_Name          Location  \
# 0                                     Kalpataru Radiance     Goregaon West
# 1                      Monte Verita North Annexe Phase 1     Borivali East
# 2      Sheth VASANTOASIS BLOSSOM BLDG 20 WING A AND W...            khopte
# 3                        DLH The Park Residences Phase 1      Andheri West
# 4                           Oberoi Eternia Towers A to D       Mulund West
# ...                                                  ...               ...
# 14964                                                NaN       Mulund West
# 14965                                                NaN    Santacruz East
# 14966                                                NaN    Mira Road West
# 14967                                                NaN     Borivali West
# 14968                                                NaN   Vile Parle East
#
# ...

# %%
nan_counts = df.isna().sum()
nan_counts
# Out:
# Property_Name    5029
# Location            0
# Price               0
# Built-up Area       0
# Bedroom             0
# Property_Age     1997
# Furnish            41
# dtype: int64

# %%
df['Built-up Area'] = df['Built-up Area'].str.split(' ').str[0].astype(int)
df['Bedroom'] = df['Bedroom'].str.split(' ').str[0].astype(float)
df['Price Unit'] = df['Price'].str.split(' ').str[1]
for i in range (0,len(df)):
    if df['Price Unit'][i] == 'Cr':
        df['Price'][i] = float(df['Price'][i].split(' ')[0]) * 10000000
    elif df['Price Unit'][i] == 'L' or df['Price Unit'][i] == 'Lacs' or df['Price Unit'][i] == 'Lac' or df['Price Unit'][i] == 'L(negotiable)':
        df['Price'][i] = float(df['Price'][i].split(' ')[0]) * 100000
    else:
      df['Price'][i] = float(df['Price'][i].replace(',',''))
df['Property_Age'] = df['Property_Age'].dropna().apply(lambda x: float(x.split()[0]))
df['Property_Age'].fillna(df['Property_Age'].median(), inplace=True)
df['Property_Name'] = df['Property_Name'].fillna('Unnamed Property')
df['Furnish'] = df['Furnish'].fillna('Unfurnished')
df
# Out:
#                                            Property_Name          Location  \
# 0                                     Kalpataru Radiance     Goregaon West
# 1                      Monte Verita North Annexe Phase 1     Borivali East
# 2      Sheth VASANTOASIS BLOSSOM BLDG 20 WING A AND W...            khopte
# 3                        DLH The Park Residences Phase 1      Andheri West
# 4                           Oberoi Eternia Towers A to D       Mulund West
# ...                                                  ...               ...
# 14964                                   Unnamed Property       Mulund West
# 14965                                   Unnamed Property    Santacruz East
# 14966                                   Unnamed Property    Mira Road West
# 14967                                   Unnamed Property     Borivali West
# 14968                                   Unnamed Property   Vile Parle East
#
# ...

# %%
df.isna().sum()
# Out:
# Property_Name    0
# Location         0
# Price            0
# Built-up Area    0
# Bedroom          0
# Property_Age     0
# Furnish          0
# Price Unit       3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 745

# %%
df = df.drop_duplicates(ignore_index=True)
df
# Out:
#                                            Property_Name          Location  \
# 0                                     Kalpataru Radiance     Goregaon West
# 1                      Monte Verita North Annexe Phase 1     Borivali East
# 2      Sheth VASANTOASIS BLOSSOM BLDG 20 WING A AND W...            khopte
# 3                        DLH The Park Residences Phase 1      Andheri West
# 4                           Oberoi Eternia Towers A to D       Mulund West
# ...                                                  ...               ...
# 14219                                   Unnamed Property       Mulund West
# 14220                                   Unnamed Property    Santacruz East
# 14221                                   Unnamed Property    Mira Road West
# 14222                                   Unnamed Property     Borivali West
# 14223                                   Unnamed Property   Vile Parle East
#
# ...

# %%
print('Shape of Data :', df.shape)
df
# Out:
# Shape of Data : (14224, 8)
#                                            Property_Name          Location  \
# 0                                     Kalpataru Radiance     Goregaon West
# 1                      Monte Verita North Annexe Phase 1     Borivali East
# 2      Sheth VASANTOASIS BLOSSOM BLDG 20 WING A AND W...            khopte
# 3                        DLH The Park Residences Phase 1      Andheri West
# 4                           Oberoi Eternia Towers A to D       Mulund West
# ...                                                  ...               ...
# 14219                                   Unnamed Property       Mulund West
# 14220                                   Unnamed Property    Santacruz East
# 14221                                   Unnamed Property    Mira Road West
# 14222                                   Unnamed Property     Borivali West
# 14223                                   Unnamed Property   Vile Parle East
#
# ...

# %%
df.to_csv('Property.csv', index=False)
